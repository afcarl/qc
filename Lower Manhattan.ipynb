# %%
# Display plots in the notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import geopandas as gp
import pandas as pd
from shapely.geometry import Point
import pylab as pl
pl.style.use('fivethirtyeight')

# %%
lm = gp.read_file('LM_Study_Area')

# %%
lm.plot()

# %%
tweets = pd.read_csv('tweets.csv')

# %%
tweets.columns
# Out:
# Index([u'tweetid', u'timestamp', u'latitude', u'longitude', u'tweet',
#        u'userid', u'raw'],
#       dtype='object')

# %%
tweets.drop('raw', inplace=True, axis=1)

# %%
tweets.columns
# Out:
# Index([u'tweetid', u'timestamp', u'latitude', u'longitude', u'tweet',
#        u'userid'],
#       dtype='object')

# %%
lm.columns
# Out:
# Index([u'BBL', u'BLOCKID10', u'geometry'], dtype='object')

# %%
tweets['geometry'] = tweets.apply(lambda x: Point(x['longitude'], x['latitude']), axis=1)

# %%
tweets_g = gp.GeoSeries(tweets['geometry'])

# %%
r = tweets_g.intersects(lm)

# %%
lm.to_crs(epsg=4326, inplace=True)

# %%
lm
# Out:
#             BBL     BLOCKID10  \
# 0    1000297501  3.606100e+14
# 1    1000290070  3.606100e+14
# 2    1000290086  3.606100e+14
# 3    1000290073  3.606100e+14
# 4    1000277502  3.606100e+14
# 5    1000297503  3.606100e+14
# 6    1000290048  3.606100e+14
# 7    1000290046  3.606100e+14
# 8    1000290045  3.606100e+14
# 9    1000290047  3.606100e+14
# 10   1000290043  3.606100e+14
# 11   1000290001  3.606100e+14
# 12   1000330011  3.606100e+14
# 13   1000330022  3.606100e+14
# 14   1000350010  3.606100e+14
# 15   1000350001  3.606100e+14
# 16   1000707501  3.606100e+14
# 17   1000717501  3.606100e+14
# 18   1000340037  3.606100e+14
# 19   1000030003  3.606100e+14
# 20   1000390038  3.606100e+14
# 21   1000390006  3.606100e+14
# 22   1000397501  3.606100e+14
# 23   1000390040  3.606100e+14
# 24   1000390001  3.606100e+14
# 25   1000390004  3.606100e+14
# 26   1000390041  3.606100e+14
# 27   1000280015  3.606100e+14
# 28   1000287501  3.606100e+14
# 29   1000280012  3.606100e+14
# ...

# %%
r = tweets_g.intersects(lm)

# %%
lm.intersects(tweets_g)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 548196    False
# 548197    False
# 548198    False
# 548199    False
# 548200    False
# 548201    False
# 548202    False
# 548203    False
# 548204    False
# 548205    False
# 548206    False
# 548207    False
# 548208    False
# 548209    False
# 548210    False
# 548211    False
# 548212    False
# 548213    False
# 548214    False
# 548215    False
# 548216    False
# 548217    False
# 548218    False
# 548219    False
# ...

# %%
tweets_g.intersects(lm)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 548196    False
# 548197    False
# 548198    False
# 548199    False
# 548200    False
# 548201    False
# 548202    False
# 548203    False
# 548204    False
# 548205    False
# 548206    False
# 548207    False
# 548208    False
# 548209    False
# 548210    False
# 548211    False
# 548212    False
# 548213    False
# 548214    False
# 548215    False
# 548216    False
# 548217    False
# 548218    False
# 548219    False
# ...

# %%
r = lm.contains(tweets_g)
r.any()
# Out:
# False

# %%
tweets_g
# Out:
# 0                 POINT (-74.07559599999999 40.626242)
# 1                       POINT (-74.2107006 40.6639916)
# 2                       POINT (-74.2749524 40.5928766)
# 3                 POINT (-74.021759 40.61914829999999)
# 4                         POINT (-74.106072 40.630363)
# 5                POINT (-74.02316280000001 40.6289597)
# 6                     POINT (-74.07266953 40.64406788)
# 7                       POINT (-74.0064354 40.6548713)
# 8                         POINT (-74.279016 40.486719)
# 9                       POINT (-74.2845911 40.5576044)
# 10                      POINT (-74.2749524 40.5928766)
# 11                      POINT (-74.3300437 40.5462509)
# 12                    POINT (-74.26000000000001 40.51)
# 13                    POINT (-73.99527925 40.60499462)
# 14               POINT (-74.00386809999999 40.6075783)
# 15                        POINT (-74.2770633 40.65376)
# 16              POINT (-74.17739152999999 40.69664827)
# ...

# %%
figure, ax = pl.subplots(figsize=(16,16))
lm.plot(axes=ax)
tweets_g[:5000].plot(axes=ax)
ax.set_xlim([-74.02, -74])
ax.set_ylim([40.7,40.71])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\Jeremy\Anaconda\lib\site-packages\IPython\core\interactiveshell.pyc in run_code(self, code_obj, result)
#    3050             if result is not None:
#    3051                 result.error_in_exec = sys.exc_info()[1]
# -> 3052             self.showtraceback()
#    3053         else:
#    3054             outflag = 0
#
# c:\Users\Jeremy\Anaconda\lib\site-packages\IPython\core\interactiveshell.pyc in showtraceback(self, exc_tuple, filename, tb_offset, exception_only)
#    1851                                             value, tb, tb_offset=tb_offset)
#    1852
# -> 1853                     self._showtraceback(etype, value, stb)
#    1854                     if self.call_pdb:
#    1855                         # drop into debugger
#
# ...

# %%
tweets_g[:1000].plot()
